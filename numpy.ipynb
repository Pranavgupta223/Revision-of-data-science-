# %% [markdown]
# # Revise numpy with Me

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 6
#       2 import pandas as pd
#       3 df = {'Hello':[1,2,3],
#       4       "Hey":[4,5,6]}
# ----> 6 hello = pd.read_df(df)
#
# AttributeError: module 'pandas' has no attribute 'read_df'
